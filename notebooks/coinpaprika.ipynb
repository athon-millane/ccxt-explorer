# %% [markdown]
# ### Pull in existing data

# %%
import sys; sys.path.append('../src')
from utils.data import load_data, get_history

data,_ =load_data()

# %%
history = get_history(top_markets()[:5], timeframe='1m', limit=2000)

# %% [markdown]
# ### Evaluate `coinpaprika` API

# %%
from coinpaprika import client as Coinpaprika

# client
client = Coinpaprika.Client()

coins  = client.coins()
huobi  = client.exchange("huobi", quotes="USD")
huobi_markets = client.exchange_markets("huobi", quotes="USD")

# %% [markdown]
# ### Top `n` markets in `huobi` exchange by market cap

# %%
def top_markets(exchange='huobi', quote='USDT'):
    # client
    client = Coinpaprika.Client()
    coins  = client.coins()
    markets = client.exchange_markets(exchange, quotes="USD")
    return [m['pair'] for c in coins for m in markets if (m['base_currency_id'] == c['id'] and m['pair'].split('/')[-1] == quote)]

top_markets()
# Out:
# ['BTC/USDT',
#  'ETH/USDT',
#  'XRP/USDT',
#  'BCH/USDT',
#  'BSV/USDT',
#  'LTC/USDT',
#  'EOS/USDT',
#  'XTZ/USDT',
#  'LINK/USDT',
#  'XLM/USDT']

# %%
client.markets("btc-bitcoin", quotes="USD")
# Out:
# Signature: client.markets(coin_id, **params)
# Docstring: <no docstring>
# File:      ~/anaconda3/envs/rltrade/lib/python3.7/site-packages/coinpaprika/client.py
# Type:      method

# %%
# Get coin by ID (example: btc-bitcoin)
client.coin("btc-bitcoin")

# Get tweets by coin ID (max 50 tweets)
client.twitter("btc-bitcoin")

# Get coin events by coin ID
client.events("btc-bitcoin")

# Get exchanges by coin ID
client.exchanges("btc-bitcoin")

# Get markets by coin ID (USD,BTC,ETH,PLN)
client.markets("btc-bitcoin", quotes="USD")

# Get 24h OHLC candle (USD,BTC)
client.candle("btc-bitcoin")

# Get historical OHLCV information for a specific coin (USD,BTC)
client.candles("btc-bitcoin", start="2019-01-11T00:00:00Z")

# Get today OHLC (can change every each request until actual close of the day at 23:59:59)
client.today("btc-bitcoin")

# Get people by ID (example: vitalik-buterin)
client.people("vitalik-buterin")

# List tags
client.tags()

client.tags(additional_fields="coins,icos")

# Get tag by ID
client.tag("blockchain-service")

# Get tickers for all coins (USD,BTC,ETH)
client.tickers()

# Get ticker information for a specific coin (USD,BTC,ETH)
client.ticker("btc-bitcoin")

# Get historical ticker information for a specific coin (USD,BTC,ETH)
client.historical("btc-bitcoin", start="2019-04-11T00:00:00Z")

# List exchanges
client.exchange_list()

# Get exchange by ID
client.exchange("binance", quotes="USD")

# Get markets by exchange ID (USD,BTC,ETH,PLN) with quotes USD
client.exchange_markets("binance", quotes="USD")

# Search
client.search(q="btc",c="currencies,exchanges,icos,people,tags", modifier="symbol_search", limit=42)

# Price converter
client.price_converter(base_currency_id="btc-bitcoin", quote_currency_id="usd-us-dollars", amount=1337)
# Out:
# [{'id': 'btc-bitcoin',
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'rank': 1,
#   'is_new': False,
#   'is_active': True,
#   'type': 'coin'},
#  {'id': 'eth-ethereum',
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'rank': 2,
#   'is_new': False,
#   'is_active': True,
#   'type': 'coin'},
#  {'id': 'xrp-xrp',
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'rank': 3,
#   'is_new': False,
#   'is_active': True,
#   'type': 'coin'},
#  {'id': 'usdt-tether',
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'rank': 4,
#   'is_new': False,
#   'is_active': True,
#   'type': 'token'},
#  {'id': 'bch-bitcoin-cash',
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'rank': 5,
#   'is_new': False,
#   'is_active': True,
#   'type': 'coin'}]

# %%
client.candle("btc-bitcoin")
# Out:
# [{'time_open': '2020-04-09T00:00:00Z',
#   'time_close': '2020-04-09T23:59:59Z',
#   'open': 7328.86714826,
#   'high': 7355.4492152,
#   'low': 7185.53878895,
#   'close': 7315.24479261,
#   'volume': 25021779913,
#   'market_cap': 134214093751}]

# %%
client.candles("btc-bitcoin", start="2019-01-11T00:00:00Z")
# Out:
# [{'time_open': '2019-01-11T00:00:00Z',
#   'time_close': '2019-01-11T23:59:59Z',
#   'open': 3663.31971064,
#   'high': 3686.79541619,
#   'low': 3631.54852907,
#   'close': 3655.71457125,
#   'volume': 3761766983,
#   'market_cap': 64016054028}]

# %%
client.historical("btc-bitcoin", start="2019-01-11T00:00:00Z")
# Out:
# [{'timestamp': '2019-01-11T00:00:00Z',
#   'price': 3663.32,
#   'volume_24h': 4987311985,
#   'market_cap': 64016054028},
#  {'timestamp': '2019-01-11T00:05:00Z',
#   'price': 3655.06,
#   'volume_24h': 4960396698,
#   'market_cap': 63871692473},
#  {'timestamp': '2019-01-11T00:10:00Z',
#   'price': 3658.24,
#   'volume_24h': 4969202378,
#   'market_cap': 63927222526},
#  {'timestamp': '2019-01-11T00:15:00Z',
#   'price': 3655.74,
#   'volume_24h': 4979511382,
#   'market_cap': 63883776493},
#  {'timestamp': '2019-01-11T00:20:00Z',
#   'price': 3662.42,
#   'volume_24h': 5000448451,
#   'market_cap': 64000529718},
#  {'timestamp': '2019-01-11T00:25:00Z',
#   'price': 3666.98,
#   'volume_24h': 5014878315,
#   'market_cap': 64080497066},
#  {'timestamp': '2019-01-11T00:30:00Z',
#   'price': 3668.13,
#   'volume_24h': 5019445161,
#   'market_cap': 64100558639},
#  {'timestamp': '2019-01-11T00:35:00Z',
#   'price': 3668.79,
#   'volume_24h': 5028038772,
#   'market_cap': 64111973535},
#  {'timestamp': '2019-01-11T00:40:00Z',
#   'price': 3667.12,
#   'volume_24h': 5047552034,
#   'market_cap': 64082928149},
#  {'timestamp': '2019-01-11T00:45:00Z',
#   'price': 3669.88,
#   'volume_24h': 5057871259,
#   'market_cap': 64131080722},
#  {'timestamp': '2019-01-11T00:50:00Z',
#   'price': 3672.76,
#   'volume_24h': 5079946883,
#   'market_cap': 64181549047},
#  {'timestamp': '2019-01-11T00:55:00Z',
#   'price': 3673.22,
#   'volume_24h': 5081618193,
#   'market_cap': 64189674109},
#  {'timestamp': '2019-01-11T01:00:00Z',
#   'price': 3675.96,
#   'volume_24h': 5090851236,
#   'market_cap': 64237605059},
#  {'timestamp': '2019-01-11T01:05:00Z',
#   'price': 3676.57,
#   'volume_24h': 5082350923,
#   'market_cap': 64248270644},
#  {'timestamp': '2019-01-11T01:10:00Z',
#   'price': 3678.79,
#   'volume_24h': 5082195377,
#   'market_cap': 64287058265},
#  {'timestamp': '2019-01-11T01:15:00Z',
#   'price': 3679.31,
#   'volume_24h': 5083580099,
#   'market_cap': 64296195649},
#  {'timestamp': '2019-01-11T01:20:00Z',
#   'price': 3679.22,
#   'volume_24h': 5078004366,
#   'market_cap': 64294530172},
#  {'timestamp': '2019-01-11T01:25:00Z',
#   'price': 3674.57,
#   'volume_24h': 5078015884,
#   'market_cap': 64213369107},
#  {'timestamp': '2019-01-11T01:30:00Z',
#   'price': 3673.76,
#   'volume_24h': 5077578255,
#   'market_cap': 64199264787},
#  {'timestamp': '2019-01-11T01:35:00Z',
#   'price': 3673.52,
#   'volume_24h': 5080520189,
#   'market_cap': 64194920505},
#  {'timestamp': '2019-01-11T01:40:00Z',
#   'price': 3673.49,
#   'volume_24h': 5085797213,
#   'market_cap': 64194485434},
#  {'timestamp': '2019-01-11T01:45:00Z',
#   'price': 3668.02,
#   'volume_24h': 5079934518,
#   'market_cap': 64098934959},
#  {'timestamp': '2019-01-11T01:50:00Z',
#   'price': 3666.21,
#   'volume_24h': 5081194820,
#   'market_cap': 64067411100},
#  {'timestamp': '2019-01-11T01:55:00Z',
#   'price': 3665.89,
#   'volume_24h': 5080451718,
#   'market_cap': 64061787584},
#  {'timestamp': '2019-01-11T02:00:00Z',
#   'price': 3668.86,
#   'volume_24h': 5085458016,
#   'market_cap': 64113621672},
#  {'timestamp': '2019-01-11T02:05:00Z',
#   'price': 3666.79,
#   'volume_24h': 5056310579,
#   'market_cap': 64077539412},
#  {'timestamp': '2019-01-11T02:10:00Z',
#   'price': 3669.34,
#   'volume_24h': 5077988900,
#   'market_cap': 64122097770},
#  {'timestamp': '2019-01-11T02:15:00Z',
#   'price': 3666.34,
#   'volume_24h': 5075495186,
#   'market_cap': 64069666722},
#  {'timestamp': '2019-01-11T02:20:00Z',
#   'price': 3666.58,
#   'volume_24h': 5072851206,
#   'market_cap': 64073862417},
#  {'timestamp': '2019-01-11T02:25:00Z',
#   'price': 3666.03,
#   'volume_24h': 5077143369,
#   'market_cap': 64064210038},
#  {'timestamp': '2019-01-11T02:30:00Z',
#   'price': 3666.94,
#   'volume_24h': 5079025236,
#   'market_cap': 64080238633},
#  {'timestamp': '2019-01-11T02:35:00Z',
#   'price': 3661.79,
#   'volume_24h': 5072992712,
#   'market_cap': 63990164247},
#  {'timestamp': '2019-01-11T02:40:00Z',
#   'price': 3660.3,
#   'volume_24h': 5079902525,
#   'market_cap': 63964121180},
#  {'timestamp': '2019-01-11T02:45:00Z',
#   'price': 3658.22,
#   'volume_24h': 5083553765,
#   'market_cap': 63927800630},
#  {'timestamp': '2019-01-11T02:50:00Z',
#   'price': 3655.09,
#   'volume_24h': 5082340309,
#   'market_cap': 63873285886},
#  {'timestamp': '2019-01-11T02:55:00Z',
#   'price': 3656.29,
#   'volume_24h': 5079361088,
#   'market_cap': 63894247373},
#  {'timestamp': '2019-01-11T03:00:00Z',
#   'price': 3652.59,
#   'volume_24h': 5081172720,
#   'market_cap': 63829533001},
#  {'timestamp': '2019-01-11T03:05:00Z',
#   'price': 3653.59,
#   'volume_24h': 5087541647,
#   'market_cap': 63847145474},
#  {'timestamp': '2019-01-11T03:10:00Z',
#   'price': 3656.14,
#   'volume_24h': 5092840141,
#   'market_cap': 63891636745},
#  {'timestamp': '2019-01-11T03:15:00Z',
#   'price': 3654.77,
#   'volume_24h': 5093331161,
#   'market_cap': 63867909799},
#  {'timestamp': '2019-01-11T03:20:00Z',
#   'price': 3656.94,
#   'volume_24h': 5100097527,
#   'market_cap': 63905769542},
#  {'timestamp': '2019-01-11T03:25:00Z',
#   'price': 3655.3,
#   'volume_24h': 5104306786,
#   'market_cap': 63877250842},
#  {'timestamp': '2019-01-11T03:30:00Z',
#   'price': 3655.14,
#   'volume_24h': 5108866724,
#   'market_cap': 63874492089},
#  {'timestamp': '2019-01-11T03:35:00Z',
#   'price': 3657.86,
#   'volume_24h': 5114558150,
#   'market_cap': 63921957169},
#  {'timestamp': '2019-01-11T03:40:00Z',
#   'price': 3656.18,
#   'volume_24h': 5115190595,
#   'market_cap': 63892664548},
#  {'timestamp': '2019-01-11T03:45:00Z',
#   'price': 3658.82,
#   'volume_24h': 5116333511,
#   'market_cap': 63938803825},
#  {'timestamp': '2019-01-11T03:50:00Z',
#   'price': 3656.12,
#   'volume_24h': 5115175721,
#   'market_cap': 63891539725},
#  {'timestamp': '2019-01-11T03:55:00Z',
#   'price': 3657.24,
#   'volume_24h': 5124783295,
#   'market_cap': 63911270945},
#  {'timestamp': '2019-01-11T04:00:00Z',
#   'price': 3656.36,
#   'volume_24h': 5129568335,
#   'market_cap': 63895863589},
#  {'timestamp': '2019-01-11T04:05:00Z',
#   'price': 3653.89,
#   'volume_24h': 5101843194,
#   'market_cap': 63852966078},
#  {'timestamp': '2019-01-11T04:10:00Z',
#   'price': 3650.46,
#   'volume_24h': 5100366207,
#   'market_cap': 63792887841},
#  {'timestamp': '2019-01-11T04:15:00Z',
#   'price': 3649.13,
#   'volume_24h': 5105932078,
#   'market_cap': 63769753896},
#  {'timestamp': '2019-01-11T04:20:00Z',
#   'price': 3649.81,
#   'volume_24h': 5112654534,
#   'market_cap': 63781668680},
#  {'timestamp': '2019-01-11T04:25:00Z',
#   'price': 3636.06,
#   'volume_24h': 5100397382,
#   'market_cap': 63541324177},
#  {'timestamp': '2019-01-11T04:30:00Z',
#   'price': 3635.48,
#   'volume_24h': 5108662717,
#   'market_cap': 63531272153},
#  {'timestamp': '2019-01-11T04:35:00Z',
#   'price': 3635.9,
#   'volume_24h': 5125307337,
#   'market_cap': 63538541028},
#  {'timestamp': '2019-01-11T04:40:00Z',
#   'price': 3631.55,
#   'volume_24h': 5130069798,
#   'market_cap': 63462490798},
#  {'timestamp': '2019-01-11T04:45:00Z',
#   'price': 3637.64,
#   'volume_24h': 5142098400,
#   'market_cap': 63569049772},
#  {'timestamp': '2019-01-11T04:50:00Z',
#   'price': 3636.07,
#   'volume_24h': 5143710410,
#   'market_cap': 63541554059},
#  {'timestamp': '2019-01-11T04:55:00Z',
#   'price': 3636.51,
#   'volume_24h': 5153342986,
#   'market_cap': 63549296282},
#  {'timestamp': '2019-01-11T05:00:00Z',
#   'price': 3639.79,
#   'volume_24h': 5158235273,
#   'market_cap': 63606556343},
#  {'timestamp': '2019-01-11T05:05:00Z',
#   'price': 3643.85,
#   'volume_24h': 5150799063,
#   'market_cap': 63677526703},
#  {'timestamp': '2019-01-11T05:10:00Z',
#   'price': 3647.96,
#   'volume_24h': 5150922998,
#   'market_cap': 63749455779},
#  {'timestamp': '2019-01-11T05:15:00Z',
#   'price': 3645.33,
#   'volume_24h': 5149180492,
#   'market_cap': 63703588235},
#  {'timestamp': '2019-01-11T05:20:00Z',
#   'price': 3645.41,
#   'volume_24h': 5152179325,
#   'market_cap': 63704832746},
#  {'timestamp': '2019-01-11T05:25:00Z',
#   'price': 3644,
#   'volume_24h': 5140718196,
#   'market_cap': 63680454932},
#  {'timestamp': '2019-01-11T05:30:00Z',
#   'price': 3642.98,
#   'volume_24h': 5135212445,
#   'market_cap': 63662602379},
#  {'timestamp': '2019-01-11T05:35:00Z',
#   'price': 3644.41,
#   'volume_24h': 5134530486,
#   'market_cap': 63687573997},
#  {'timestamp': '2019-01-11T05:40:00Z',
#   'price': 3644.82,
#   'volume_24h': 5129091780,
#   'market_cap': 63694776567},
#  {'timestamp': '2019-01-11T05:45:00Z',
#   'price': 3641.72,
#   'volume_24h': 5120395256,
#   'market_cap': 63640507457},
#  {'timestamp': '2019-01-11T05:50:00Z',
#   'price': 3643.76,
#   'volume_24h': 5126397998,
#   'market_cap': 63676230331},
#  {'timestamp': '2019-01-11T05:55:00Z',
#   'price': 3647.36,
#   'volume_24h': 5134932830,
#   'market_cap': 63739134335},
#  {'timestamp': '2019-01-11T06:00:00Z',
#   'price': 3651.08,
#   'volume_24h': 5127300614,
#   'market_cap': 63804102123},
#  {'timestamp': '2019-01-11T06:05:00Z',
#   'price': 3649.36,
#   'volume_24h': 5113414749,
#   'market_cap': 63774052988},
#  {'timestamp': '2019-01-11T06:10:00Z',
#   'price': 3651.48,
#   'volume_24h': 5109927648,
#   'market_cap': 63811115895},
#  {'timestamp': '2019-01-11T06:15:00Z',
#   'price': 3653.49,
#   'volume_24h': 5107982770,
#   'market_cap': 63846318246},
#  {'timestamp': '2019-01-11T06:20:00Z',
#   'price': 3654.69,
#   'volume_24h': 5105514866,
#   'market_cap': 63867209279},
#  {'timestamp': '2019-01-11T06:25:00Z',
#   'price': 3656.92,
#   'volume_24h': 5108687797,
#   'market_cap': 63906250048},
#  {'timestamp': '2019-01-11T06:30:00Z',
#   'price': 3657.64,
#   'volume_24h': 5102081593,
#   'market_cap': 63918725216},
#  {'timestamp': '2019-01-11T06:35:00Z',
#   'price': 3659.06,
#   'volume_24h': 5059563600,
#   'market_cap': 63943562012},
#  {'timestamp': '2019-01-11T06:40:00Z',
#   'price': 3664.18,
#   'volume_24h': 4987599800,
#   'market_cap': 64033060343},
#  {'timestamp': '2019-01-11T06:45:00Z',
#   'price': 3663.18,
#   'volume_24h': 4941191476,
#   'market_cap': 64015611098},
#  {'timestamp': '2019-01-11T06:50:00Z',
#   'price': 3661.34,
#   'volume_24h': 4862555465,
#   'market_cap': 63983393106},
#  {'timestamp': '2019-01-11T06:55:00Z',
#   'price': 3659.37,
#   'volume_24h': 4813715474,
#   'market_cap': 63949069557},
#  {'timestamp': '2019-01-11T07:00:00Z',
#   'price': 3663.49,
#   'volume_24h': 4776596083,
#   'market_cap': 64020995004},
#  {'timestamp': '2019-01-11T07:05:00Z',
#   'price': 3662.62,
#   'volume_24h': 4731382403,
#   'market_cap': 64005905692},
#  {'timestamp': '2019-01-11T07:10:00Z',
#   'price': 3666.71,
#   'volume_24h': 4708982999,
#   'market_cap': 64077512253},
#  {'timestamp': '2019-01-11T07:15:00Z',
#   'price': 3665.95,
#   'volume_24h': 4688359194,
#   'market_cap': 64064147647},
#  {'timestamp': '2019-01-11T07:20:00Z',
#   'price': 3663.62,
#   'volume_24h': 4674048374,
#   'market_cap': 64023391832},
#  {'timestamp': '2019-01-11T07:25:00Z',
#   'price': 3665.97,
#   'volume_24h': 4661558944,
#   'market_cap': 64064563707},
#  {'timestamp': '2019-01-11T07:30:00Z',
#   'price': 3659.78,
#   'volume_24h': 4643943829,
#   'market_cap': 63956292640},
#  {'timestamp': '2019-01-11T07:35:00Z',
#   'price': 3662.33,
#   'volume_24h': 4641028150,
#   'market_cap': 64001064276},
#  {'timestamp': '2019-01-11T07:40:00Z',
#   'price': 3659.9,
#   'volume_24h': 4629873644,
#   'market_cap': 63958646285},
#  {'timestamp': '2019-01-11T07:45:00Z',
#   'price': 3661.85,
#   'volume_24h': 4625341889,
#   'market_cap': 63992784161},
#  {'timestamp': '2019-01-11T07:50:00Z',
#   'price': 3662.98,
#   'volume_24h': 4619420003,
#   'market_cap': 64012504540},
#  {'timestamp': '2019-01-11T07:55:00Z',
#   'price': 3668.64,
#   'volume_24h': 4620244043,
#   'market_cap': 64111551376},
#  {'timestamp': '2019-01-11T08:00:00Z',
#   'price': 3667.01,
#   'volume_24h': 4612941316,
#   'market_cap': 64082944401},
#  {'timestamp': '2019-01-11T08:05:00Z',
#   'price': 3671.91,
#   'volume_24h': 4594973656,
#   'market_cap': 64168647319},
#  {'timestamp': '2019-01-11T08:10:00Z',
#   'price': 3670.14,
#   'volume_24h': 4587106042,
#   'market_cap': 64137756762},
#  {'timestamp': '2019-01-11T08:15:00Z',
#   'price': 3669.55,
#   'volume_24h': 4587946501,
#   'market_cap': 64127468878},
#  {'timestamp': '2019-01-11T08:20:00Z',
#   'price': 3670.24,
#   'volume_24h': 4580807646,
#   'market_cap': 64139568273},
#  {'timestamp': '2019-01-11T08:25:00Z',
#   'price': 3673.66,
#   'volume_24h': 4582378247,
#   'market_cap': 64199212476},
#  {'timestamp': '2019-01-11T08:30:00Z',
#   'price': 3671.64,
#   'volume_24h': 4573548789,
#   'market_cap': 64164066849},
#  {'timestamp': '2019-01-11T08:35:00Z',
#   'price': 3670.8,
#   'volume_24h': 4564243630,
#   'market_cap': 64149424222},
#  {'timestamp': '2019-01-11T08:40:00Z',
#   'price': 3676.68,
#   'volume_24h': 4555163932,
#   'market_cap': 64252081301},
#  {'timestamp': '2019-01-11T08:45:00Z',
#   'price': 3676.5,
#   'volume_24h': 4551482506,
#   'market_cap': 64248889228},
#  {'timestamp': '2019-01-11T08:50:00Z',
#   'price': 3686.18,
#   'volume_24h': 4572634257,
#   'market_cap': 64418136287},
#  {'timestamp': '2019-01-11T08:55:00Z',
#   'price': 3684.78,
#   'volume_24h': 4578006672,
#   'market_cap': 64393877876},
#  {'timestamp': '2019-01-11T09:00:00Z',
#   'price': 3679.97,
#   'volume_24h': 4576484557,
#   'market_cap': 64309838394},
#  {'timestamp': '2019-01-11T09:05:00Z',
#   'price': 3677.65,
#   'volume_24h': 4545287620,
#   'market_cap': 64269210082},
#  {'timestamp': '2019-01-11T09:10:00Z',
#   'price': 3675.75,
#   'volume_24h': 4524425482,
#   'market_cap': 64236100488},
#  {'timestamp': '2019-01-11T09:15:00Z',
#   'price': 3676.3,
#   'volume_24h': 4523034026,
#   'market_cap': 64245611420},
#  {'timestamp': '2019-01-11T09:20:00Z',
#   'price': 3680.54,
#   'volume_24h': 4522621760,
#   'market_cap': 64319732970},
#  {'timestamp': '2019-01-11T09:25:00Z',
#   'price': 3677.32,
#   'volume_24h': 4516666355,
#   'market_cap': 64263431400},
#  {'timestamp': '2019-01-11T09:30:00Z',
#   'price': 3676.77,
#   'volume_24h': 4498682358,
#   'market_cap': 64254043724},
#  {'timestamp': '2019-01-11T09:35:00Z',
#   'price': 3674.69,
#   'volume_24h': 4492085011,
#   'market_cap': 64217769633},
#  {'timestamp': '2019-01-11T09:40:00Z',
#   'price': 3675.95,
#   'volume_24h': 4478442672,
#   'market_cap': 64239705694},
#  {'timestamp': '2019-01-11T09:45:00Z',
#   'price': 3673.22,
#   'volume_24h': 4467130469,
#   'market_cap': 64192021643},
#  {'timestamp': '2019-01-11T09:50:00Z',
#   'price': 3676.63,
#   'volume_24h': 4465934582,
#   'market_cap': 64251670779},
#  {'timestamp': '2019-01-11T09:55:00Z',
#   'price': 3678.94,
#   'volume_24h': 4434439240,
#   'market_cap': 64291961541},
#  {'timestamp': '2019-01-11T10:00:00Z',
#   'price': 3675.78,
#   'volume_24h': 4406560352,
#   'market_cap': 64236791792},
#  {'timestamp': '2019-01-11T10:05:00Z',
#   'price': 3671.21,
#   'volume_24h': 4380460067,
#   'market_cap': 64156928632},
#  {'timestamp': '2019-01-11T10:10:00Z',
#   'price': 3672.88,
#   'volume_24h': 4370830345,
#   'market_cap': 64186132955},
#  {'timestamp': '2019-01-11T10:15:00Z',
#   'price': 3672.1,
#   'volume_24h': 4366282744,
#   'market_cap': 64172441131},
#  {'timestamp': '2019-01-11T10:20:00Z',
#   'price': 3673.3,
#   'volume_24h': 4362270129,
#   'market_cap': 64193492898},
#  {'timestamp': '2019-01-11T10:25:00Z',
#   'price': 3672.38,
#   'volume_24h': 4357051913,
#   'market_cap': 64177651255},
#  {'timestamp': '2019-01-11T10:30:00Z',
#   'price': 3674.3,
#   'volume_24h': 4358007739,
#   'market_cap': 64211124941},
#  {'timestamp': '2019-01-11T10:35:00Z',
#   'price': 3673.06,
#   'volume_24h': 4351445609,
#   'market_cap': 64189448903},
#  {'timestamp': '2019-01-11T10:40:00Z',
#   'price': 3667.8,
#   'volume_24h': 4345934723,
#   'market_cap': 64097603259},
#  {'timestamp': '2019-01-11T10:45:00Z',
#   'price': 3668.17,
#   'volume_24h': 4348687205,
#   'market_cap': 64104039531},
#  {'timestamp': '2019-01-11T10:50:00Z',
#   'price': 3665.12,
#   'volume_24h': 4345979468,
#   'market_cap': 64050780408},
#  {'timestamp': '2019-01-11T10:55:00Z',
#   'price': 3662.1,
#   'volume_24h': 4345031676,
#   'market_cap': 63997943813},
#  {'timestamp': '2019-01-11T11:00:00Z',
#   'price': 3664.31,
#   'volume_24h': 4359813997,
#   'market_cap': 64036606918},
#  {'timestamp': '2019-01-11T11:05:00Z',
#   'price': 3664.54,
#   'volume_24h': 4340280003,
#   'market_cap': 64040626976},
#  {'timestamp': '2019-01-11T11:10:00Z',
#   'price': 3669.39,
#   'volume_24h': 4342181716,
#   'market_cap': 64125497797},
#  {'timestamp': '2019-01-11T11:15:00Z',
#   'price': 3668.55,
#   'volume_24h': 4337780540,
#   'market_cap': 64110681762},
#  {'timestamp': '2019-01-11T11:20:00Z',
#   'price': 3668.56,
#   'volume_24h': 4332448366,
#   'market_cap': 64110950530},
#  {'timestamp': '2019-01-11T11:25:00Z',
#   'price': 3666.1,
#   'volume_24h': 4330714550,
#   'market_cap': 64067924754},
#  {'timestamp': '2019-01-11T11:30:00Z',
#   'price': 3665.84,
#   'volume_24h': 4330476420,
#   'market_cap': 64063369899},
#  {'timestamp': '2019-01-11T11:35:00Z',
#   'price': 3663.19,
#   'volume_24h': 4328838225,
#   'market_cap': 64017118812},
#  {'timestamp': '2019-01-11T11:40:00Z',
#   'price': 3661.21,
#   'volume_24h': 4325219201,
#   'market_cap': 63982465160},
#  {'timestamp': '2019-01-11T11:45:00Z',
#   'price': 3663.94,
#   'volume_24h': 4329795783,
#   'market_cap': 64030259588},
#  {'timestamp': '2019-01-11T11:50:00Z',
#   'price': 3663.47,
#   'volume_24h': 4334167935,
#   'market_cap': 64022018211},
#  {'timestamp': '2019-01-11T11:55:00Z',
#   'price': 3664.6,
#   'volume_24h': 4335400033,
#   'market_cap': 64041788018},
#  {'timestamp': '2019-01-11T12:00:00Z',
#   'price': 3664.35,
#   'volume_24h': 4335870753,
#   'market_cap': 64037439638},
#  {'timestamp': '2019-01-11T12:05:00Z',
#   'price': 3664.51,
#   'volume_24h': 4316311884,
#   'market_cap': 64040338702},
#  {'timestamp': '2019-01-11T12:10:00Z',
#   'price': 3661.28,
#   'volume_24h': 4306762213,
#   'market_cap': 63984004610},
#  {'timestamp': '2019-01-11T12:15:00Z',
#   'price': 3661.82,
#   'volume_24h': 4302569114,
#   'market_cap': 63993469107},
#  {'timestamp': '2019-01-11T12:20:00Z',
#   'price': 3660.26,
#   'volume_24h': 4299523034,
#   'market_cap': 63966165966},
#  {'timestamp': '2019-01-11T12:25:00Z',
#   'price': 3663.03,
#   'volume_24h': 4299243620,
#   'market_cap': 64014583425},
#  {'timestamp': '2019-01-11T12:30:00Z',
#   'price': 3660.3,
#   'volume_24h': 4294849164,
#   'market_cap': 63966949692},
#  {'timestamp': '2019-01-11T12:35:00Z',
#   'price': 3660.7,
#   'volume_24h': 4293560117,
#   'market_cap': 63974155805},
#  {'timestamp': '2019-01-11T12:40:00Z',
#   'price': 3656.11,
#   'volume_24h': 4287530170,
#   'market_cap': 63894009071},
#  {'timestamp': '2019-01-11T12:45:00Z',
#   'price': 3658.22,
#   'volume_24h': 4291735554,
#   'market_cap': 63930952281},
#  {'timestamp': '2019-01-11T12:50:00Z',
#   'price': 3658.48,
#   'volume_24h': 4287241259,
#   'market_cap': 63935512117},
#  {'timestamp': '2019-01-11T12:55:00Z',
#   'price': 3660.32,
#   'volume_24h': 4286507091,
#   'market_cap': 63967657440},
#  {'timestamp': '2019-01-11T13:00:00Z',
#   'price': 3661.19,
#   'volume_24h': 4290549537,
#   'market_cap': 63982831677},
#  {'timestamp': '2019-01-11T13:05:00Z',
#   'price': 3661.17,
#   'volume_24h': 4264138064,
#   'market_cap': 63982544850},
#  {'timestamp': '2019-01-11T13:10:00Z',
#   'price': 3661.03,
#   'volume_24h': 4260294010,
#   'market_cap': 63980123574},
#  {'timestamp': '2019-01-11T13:15:00Z',
#   'price': 3661.67,
#   'volume_24h': 4259170572,
#   'market_cap': 63991301416},
#  {'timestamp': '2019-01-11T13:20:00Z',
#   'price': 3661.1,
#   'volume_24h': 4254471764,
#   'market_cap': 63981328516},
#  {'timestamp': '2019-01-11T13:25:00Z',
#   'price': 3663.85,
#   'volume_24h': 4253483409,
#   'market_cap': 64029356071},
#  {'timestamp': '2019-01-11T13:30:00Z',
#   'price': 3660.98,
#   'volume_24h': 4247343360,
#   'market_cap': 63979253576},
#  {'timestamp': '2019-01-11T13:35:00Z',
#   'price': 3657.48,
#   'volume_24h': 4237676789,
#   'market_cap': 63918112329},
#  {'timestamp': '2019-01-11T13:40:00Z',
#   'price': 3657.79,
#   'volume_24h': 4233914494,
#   'market_cap': 63923471510},
#  {'timestamp': '2019-01-11T13:45:00Z',
#   'price': 3655.95,
#   'volume_24h': 4231929749,
#   'market_cap': 63891437604},
#  {'timestamp': '2019-01-11T13:50:00Z',
#   'price': 3657.52,
#   'volume_24h': 4233907567,
#   'market_cap': 63918857499},
#  {'timestamp': '2019-01-11T13:55:00Z',
#   'price': 3658.74,
#   'volume_24h': 4229876923,
#   'market_cap': 63940192997},
#  {'timestamp': '2019-01-11T14:00:00Z',
#   'price': 3658.23,
#   'volume_24h': 4228581525,
#   'market_cap': 63931193297},
#  {'timestamp': '2019-01-11T14:05:00Z',
#   'price': 3658.49,
#   'volume_24h': 4219477045,
#   'market_cap': 63935829913},
#  {'timestamp': '2019-01-11T14:10:00Z',
#   'price': 3662.94,
#   'volume_24h': 4241940935,
#   'market_cap': 64013653749},
#  {'timestamp': '2019-01-11T14:15:00Z',
#   'price': 3665.5,
#   'volume_24h': 4245510305,
#   'market_cap': 64058320164},
#  {'timestamp': '2019-01-11T14:20:00Z',
#   'price': 3666.3,
#   'volume_24h': 4258307481,
#   'market_cap': 64072407613},
#  {'timestamp': '2019-01-11T14:25:00Z',
#   'price': 3670.62,
#   'volume_24h': 4261367397,
#   'market_cap': 64147798620},
#  {'timestamp': '2019-01-11T14:30:00Z',
#   'price': 3672.3,
#   'volume_24h': 4267465320,
#   'market_cap': 64177306188},
#  {'timestamp': '2019-01-11T14:35:00Z',
#   'price': 3673.42,
#   'volume_24h': 4269154898,
#   'market_cap': 64196925780},
#  {'timestamp': '2019-01-11T14:40:00Z',
#   'price': 3670.92,
#   'volume_24h': 4268834427,
#   'market_cap': 64153222710},
#  {'timestamp': '2019-01-11T14:45:00Z',
#   'price': 3670.02,
#   'volume_24h': 4263148843,
#   'market_cap': 64137549005},
#  {'timestamp': '2019-01-11T14:50:00Z',
#   'price': 3671.07,
#   'volume_24h': 4262993726,
#   'market_cap': 64155807618},
#  {'timestamp': '2019-01-11T14:55:00Z',
#   'price': 3667.2,
#   'volume_24h': 4259701703,
#   'market_cap': 64088261144},
#  {'timestamp': '2019-01-11T15:00:00Z',
#   'price': 3667.86,
#   'volume_24h': 4262453951,
#   'market_cap': 64099874945},
#  {'timestamp': '2019-01-11T15:05:00Z',
#   'price': 3670.97,
#   'volume_24h': 4250724890,
#   'market_cap': 64154184122},
#  {'timestamp': '2019-01-11T15:10:00Z',
#   'price': 3674.31,
#   'volume_24h': 4248036846,
#   'market_cap': 64212550748},
#  {'timestamp': '2019-01-11T15:15:00Z',
#   'price': 3673.52,
#   'volume_24h': 4246952718,
#   'market_cap': 64198702940},
#  {'timestamp': '2019-01-11T15:20:00Z',
#   'price': 3672.26,
#   'volume_24h': 4252320098,
#   'market_cap': 64176733130},
#  {'timestamp': '2019-01-11T15:25:00Z',
#   'price': 3675.18,
#   'volume_24h': 4255775856,
#   'market_cap': 64227739498},
#  {'timestamp': '2019-01-11T15:30:00Z',
#   'price': 3678.48,
#   'volume_24h': 4254838240,
#   'market_cap': 64285432170},
#  {'timestamp': '2019-01-11T15:35:00Z',
#   'price': 3674.67,
#   'volume_24h': 4249248434,
#   'market_cap': 64218968187},
#  {'timestamp': '2019-01-11T15:40:00Z',
#   'price': 3672.58,
#   'volume_24h': 4241710685,
#   'market_cap': 64182351783},
#  {'timestamp': '2019-01-11T15:45:00Z',
#   'price': 3666.82,
#   'volume_24h': 4238054537,
#   'market_cap': 64081675372},
#  {'timestamp': '2019-01-11T15:50:00Z',
#   'price': 3667.64,
#   'volume_24h': 4243271566,
#   'market_cap': 64096000400},
#  {'timestamp': '2019-01-11T15:55:00Z',
#   'price': 3666.5,
#   'volume_24h': 4243539858,
#   'market_cap': 64076226220},
#  {'timestamp': '2019-01-11T16:00:00Z',
#   'price': 3665.46,
#   'volume_24h': 4244317805,
#   'market_cap': 64058068145},
#  {'timestamp': '2019-01-11T16:05:00Z',
#   'price': 3661.36,
#   'volume_24h': 4218041011,
#   'market_cap': 63986257506},
#  {'timestamp': '2019-01-11T16:10:00Z',
#   'price': 3663.4,
#   'volume_24h': 4210380380,
#   'market_cap': 64021924047},
#  {'timestamp': '2019-01-11T16:15:00Z',
#   'price': 3660.02,
#   'volume_24h': 4114475453,
#   'market_cap': 63963029127},
#  {'timestamp': '2019-01-11T16:20:00Z',
#   'price': 3663.41,
#   'volume_24h': 4058282024,
#   'market_cap': 64022169551},
#  {'timestamp': '2019-01-11T16:25:00Z',
#   'price': 3668.37,
#   'volume_24h': 4024796394,
#   'market_cap': 64108947167},
#  {'timestamp': '2019-01-11T16:30:00Z',
#   'price': 3668.01,
#   'volume_24h': 4007005371,
#   'market_cap': 64102623504},
#  {'timestamp': '2019-01-11T16:35:00Z',
#   'price': 3669.5,
#   'volume_24h': 3994485340,
#   'market_cap': 64128676125},
#  {'timestamp': '2019-01-11T16:40:00Z',
#   'price': 3667.62,
#   'volume_24h': 3969686615,
#   'market_cap': 64095953159},
#  {'timestamp': '2019-01-11T16:45:00Z',
#   'price': 3670.62,
#   'volume_24h': 3964915213,
#   'market_cap': 64148283502},
#  {'timestamp': '2019-01-11T16:50:00Z',
#   'price': 3674.07,
#   'volume_24h': 3961440528,
#   'market_cap': 64208574928},
#  {'timestamp': '2019-01-11T16:55:00Z',
#   'price': 3672.07,
#   'volume_24h': 3945344940,
#   'market_cap': 64173807651},
#  {'timestamp': '2019-01-11T17:00:00Z',
#   'price': 3668.99,
#   'volume_24h': 3929943948,
#   'market_cap': 64120034889},
#  {'timestamp': '2019-01-11T17:05:00Z',
#   'price': 3670.16,
#   'volume_24h': 3906657784,
#   'market_cap': 64140549874},
#  {'timestamp': '2019-01-11T17:10:00Z',
#   'price': 3671.12,
#   'volume_24h': 3896873386,
#   'market_cap': 64157331672},
#  {'timestamp': '2019-01-11T17:15:00Z',
#   'price': 3670.8,
#   'volume_24h': 3888956427,
#   'market_cap': 64151792314},
#  {'timestamp': '2019-01-11T17:20:00Z',
#   'price': 3671.69,
#   'volume_24h': 3885161849,
#   'market_cap': 64167374094},
#  {'timestamp': '2019-01-11T17:25:00Z',
#   'price': 3672.04,
#   'volume_24h': 3882232090,
#   'market_cap': 64173405260},
#  {'timestamp': '2019-01-11T17:30:00Z',
#   'price': 3675.46,
#   'volume_24h': 3880361311,
#   'market_cap': 64233263943},
#  {'timestamp': '2019-01-11T17:35:00Z',
#   'price': 3677.25,
#   'volume_24h': 3882362794,
#   'market_cap': 64264575821},
#  {'timestamp': '2019-01-11T17:40:00Z',
#   'price': 3676.27,
#   'volume_24h': 3878343632,
#   'market_cap': 64247494432},
#  {'timestamp': '2019-01-11T17:45:00Z',
#   'price': 3678.81,
#   'volume_24h': 3880723453,
#   'market_cap': 64291967261},
#  {'timestamp': '2019-01-11T17:50:00Z',
#   'price': 3677.61,
#   'volume_24h': 3878218551,
#   'market_cap': 64270999776},
#  {'timestamp': '2019-01-11T17:55:00Z',
#   'price': 3678.08,
#   'volume_24h': 3877696508,
#   'market_cap': 64279211505},
#  {'timestamp': '2019-01-11T18:00:00Z',
#   'price': 3673.89,
#   'volume_24h': 3874610020,
#   'market_cap': 64205916033},
#  {'timestamp': '2019-01-11T18:05:00Z',
#   'price': 3675.76,
#   'volume_24h': 3857752692,
#   'market_cap': 64238587004},
#  {'timestamp': '2019-01-11T18:10:00Z',
#   'price': 3676.34,
#   'volume_24h': 3855821316,
#   'market_cap': 64248855993},
#  {'timestamp': '2019-01-11T18:15:00Z',
#   'price': 3676.65,
#   'volume_24h': 3856955805,
#   'market_cap': 64254332864},
#  {'timestamp': '2019-01-11T18:20:00Z',
#   'price': 3673.11,
#   'volume_24h': 3848622997,
#   'market_cap': 64192382175},
#  {'timestamp': '2019-01-11T18:25:00Z',
#   'price': 3675.22,
#   'volume_24h': 3844852440,
#   'market_cap': 64229482884},
#  {'timestamp': '2019-01-11T18:30:00Z',
#   'price': 3674.36,
#   'volume_24h': 3845181080,
#   'market_cap': 64214367787},
#  {'timestamp': '2019-01-11T18:35:00Z',
#   'price': 3670.8,
#   'volume_24h': 3838695118,
#   'market_cap': 64152228003},
#  {'timestamp': '2019-01-11T18:40:00Z',
#   'price': 3670.06,
#   'volume_24h': 3839833578,
#   'market_cap': 64139171805},
#  {'timestamp': '2019-01-11T18:45:00Z',
#   'price': 3665.4,
#   'volume_24h': 3832280810,
#   'market_cap': 64057835848},
#  {'timestamp': '2019-01-11T18:50:00Z',
#   'price': 3671.24,
#   'volume_24h': 3843355876,
#   'market_cap': 64159928297},
#  {'timestamp': '2019-01-11T18:55:00Z',
#   'price': 3671.6,
#   'volume_24h': 3846717575,
#   'market_cap': 64166273236},
#  {'timestamp': '2019-01-11T19:00:00Z',
#   'price': 3673.31,
#   'volume_24h': 3844315369,
#   'market_cap': 64196028600},
#  {'timestamp': '2019-01-11T19:05:00Z',
#   'price': 3675.93,
#   'volume_24h': 3830960670,
#   'market_cap': 64241978511},
#  {'timestamp': '2019-01-11T19:10:00Z',
#   'price': 3673.92,
#   'volume_24h': 3824689273,
#   'market_cap': 64206934868},
#  {'timestamp': '2019-01-11T19:15:00Z',
#   'price': 3675.04,
#   'volume_24h': 3823903839,
#   'market_cap': 64226355055},
#  {'timestamp': '2019-01-11T19:20:00Z',
#   'price': 3674.05,
#   'volume_24h': 3811991016,
#   'market_cap': 64209068467},
#  {'timestamp': '2019-01-11T19:25:00Z',
#   'price': 3675.01,
#   'volume_24h': 3790576212,
#   'market_cap': 64225871785},
#  {'timestamp': '2019-01-11T19:30:00Z',
#   'price': 3674.59,
#   'volume_24h': 3779001668,
#   'market_cap': 64218531953},
#  {'timestamp': '2019-01-11T19:35:00Z',
#   'price': 3676.98,
#   'volume_24h': 3773521207,
#   'market_cap': 64260420360},
#  {'timestamp': '2019-01-11T19:40:00Z',
#   'price': 3676.42,
#   'volume_24h': 3766198296,
#   'market_cap': 64250594009},
#  {'timestamp': '2019-01-11T19:45:00Z',
#   'price': 3678.15,
#   'volume_24h': 3752635049,
#   'market_cap': 64280881249},
#  {'timestamp': '2019-01-11T19:50:00Z',
#   'price': 3677.82,
#   'volume_24h': 3743593734,
#   'market_cap': 64275210322},
#  {'timestamp': '2019-01-11T19:55:00Z',
#   'price': 3675.38,
#   'volume_24h': 3732487396,
#   'market_cap': 64232507780},
#  {'timestamp': '2019-01-11T20:00:00Z',
#   'price': 3678.02,
#   'volume_24h': 3726764843,
#   'market_cap': 64278673249},
#  {'timestamp': '2019-01-11T20:05:00Z',
#   'price': 3675.28,
#   'volume_24h': 3709223293,
#   'market_cap': 64230786492},
#  {'timestamp': '2019-01-11T20:10:00Z',
#   'price': 3677.13,
#   'volume_24h': 3704311634,
#   'market_cap': 64263173443},
#  {'timestamp': '2019-01-11T20:15:00Z',
#   'price': 3680.79,
#   'volume_24h': 3703032648,
#   'market_cap': 64327166034},
#  {'timestamp': '2019-01-11T20:20:00Z',
#   'price': 3680.29,
#   'volume_24h': 3704470146,
#   'market_cap': 64318305069},
#  {'timestamp': '2019-01-11T20:25:00Z',
#   'price': 3682.67,
#   'volume_24h': 3705094519,
#   'market_cap': 64359994531},
#  {'timestamp': '2019-01-11T20:30:00Z',
#   'price': 3677.06,
#   'volume_24h': 3697167257,
#   'market_cap': 64261862386},
#  {'timestamp': '2019-01-11T20:35:00Z',
#   'price': 3673.67,
#   'volume_24h': 3691762597,
#   'market_cap': 64202701604},
#  {'timestamp': '2019-01-11T20:40:00Z',
#   'price': 3675.4,
#   'volume_24h': 3693558725,
#   'market_cap': 64232979487},
#  {'timestamp': '2019-01-11T20:45:00Z',
#   'price': 3675.6,
#   'volume_24h': 3689013912,
#   'market_cap': 64236496912},
#  {'timestamp': '2019-01-11T20:50:00Z',
#   'price': 3676.98,
#   'volume_24h': 3684027439,
#   'market_cap': 64260568915},
#  {'timestamp': '2019-01-11T20:55:00Z',
#   'price': 3678.78,
#   'volume_24h': 3688958825,
#   'market_cap': 64292091579},
#  {'timestamp': '2019-01-11T21:00:00Z',
#   'price': 3673.97,
#   'volume_24h': 3682796718,
#   'market_cap': 64207958173},
#  {'timestamp': '2019-01-11T21:05:00Z',
#   'price': 3676.29,
#   'volume_24h': 3664268894,
#   'market_cap': 64248674848},
#  {'timestamp': '2019-01-11T21:10:00Z',
#   'price': 3675.43,
#   'volume_24h': 3666317193,
#   'market_cap': 64233580415},
#  {'timestamp': '2019-01-11T21:15:00Z',
#   'price': 3678.32,
#   'volume_24h': 3668227816,
#   'market_cap': 64284141204},
#  {'timestamp': '2019-01-11T21:20:00Z',
#   'price': 3675.99,
#   'volume_24h': 3664887387,
#   'market_cap': 64243494160},
#  {'timestamp': '2019-01-11T21:25:00Z',
#   'price': 3685.61,
#   'volume_24h': 3681481031,
#   'market_cap': 64411574888},
#  {'timestamp': '2019-01-11T21:30:00Z',
#   'price': 3686.8,
#   'volume_24h': 3698574261,
#   'market_cap': 64432372260},
#  {'timestamp': '2019-01-11T21:35:00Z',
#   'price': 3681.42,
#   'volume_24h': 3702937334,
#   'market_cap': 64338512392},
#  {'timestamp': '2019-01-11T21:40:00Z',
#   'price': 3677.15,
#   'volume_24h': 3702436979,
#   'market_cap': 64263767649},
#  {'timestamp': '2019-01-11T21:45:00Z',
#   'price': 3675.58,
#   'volume_24h': 3704210262,
#   'market_cap': 64236282718},
#  {'timestamp': '2019-01-11T21:50:00Z',
#   'price': 3671.98,
#   'volume_24h': 3702348922,
#   'market_cap': 64173461394},
#  {'timestamp': '2019-01-11T21:55:00Z',
#   'price': 3671.82,
#   'volume_24h': 3704849009,
#   'market_cap': 64170831021},
#  {'timestamp': '2019-01-11T22:00:00Z',
#   'price': 3672.47,
#   'volume_24h': 3705802518,
#   'market_cap': 64182191026},
#  {'timestamp': '2019-01-11T22:05:00Z',
#   'price': 3671.62,
#   'volume_24h': 3684486296,
#   'market_cap': 64167527312},
#  {'timestamp': '2019-01-11T22:10:00Z',
#   'price': 3672.27,
#   'volume_24h': 3677295025,
#   'market_cap': 64178766264},
#  {'timestamp': '2019-01-11T22:15:00Z',
#   'price': 3668.28,
#   'volume_24h': 3672544703,
#   'market_cap': 64109151161},
#  {'timestamp': '2019-01-11T22:20:00Z',
#   'price': 3664.83,
#   'volume_24h': 3670406289,
#   'market_cap': 64048743423},
#  {'timestamp': '2019-01-11T22:25:00Z',
#   'price': 3661.14,
#   'volume_24h': 3671426504,
#   'market_cap': 63984392416},
#  {'timestamp': '2019-01-11T22:30:00Z',
#   'price': 3664.91,
#   'volume_24h': 3675767257,
#   'market_cap': 64050378493},
#  {'timestamp': '2019-01-11T22:35:00Z',
#   'price': 3667.37,
#   'volume_24h': 3678171781,
#   'market_cap': 64093438892},
#  {'timestamp': '2019-01-11T22:40:00Z',
#   'price': 3663.24,
#   'volume_24h': 3676003292,
#   'market_cap': 64021177975},
#  {'timestamp': '2019-01-11T22:45:00Z',
#   'price': 3666.11,
#   'volume_24h': 3676185466,
#   'market_cap': 64071522790},
#  {'timestamp': '2019-01-11T22:50:00Z',
#   'price': 3661.92,
#   'volume_24h': 3676291675,
#   'market_cap': 63998258151},
#  {'timestamp': '2019-01-11T22:55:00Z',
#   'price': 3662.48,
#   'volume_24h': 3679445880,
#   'market_cap': 64008082840},
#  {'timestamp': '2019-01-11T23:00:00Z',
#   'price': 3660.9,
#   'volume_24h': 3676369758,
#   'market_cap': 63980532877},
#  {'timestamp': '2019-01-11T23:05:00Z',
#   'price': 3652.37,
#   'volume_24h': 3662037303,
#   'market_cap': 63831346182},
#  {'timestamp': '2019-01-11T23:10:00Z',
#   'price': 3653.2,
#   'volume_24h': 3658777947,
#   'market_cap': 63845902463},
#  {'timestamp': '2019-01-11T23:15:00Z',
#   'price': 3654.15,
#   'volume_24h': 3667583564,
#   'market_cap': 63862525823},
#  {'timestamp': '2019-01-11T23:20:00Z',
#   'price': 3652.78,
#   'volume_24h': 3671294606,
#   'market_cap': 63838605965},
#  {'timestamp': '2019-01-11T23:25:00Z',
#   'price': 3655.6,
#   'volume_24h': 3676305222,
#   'market_cap': 63888076272},
#  {'timestamp': '2019-01-11T23:30:00Z',
#   'price': 3654.84,
#   'volume_24h': 3679341189,
#   'market_cap': 63874669434},
#  {'timestamp': '2019-01-11T23:35:00Z',
#   'price': 3652.1,
#   'volume_24h': 3678842437,
#   'market_cap': 63826893083},
#  {'timestamp': '2019-01-11T23:40:00Z',
#   'price': 3639.47,
#   'volume_24h': 3700531367,
#   'market_cap': 63606081845},
#  {'timestamp': '2019-01-11T23:45:00Z',
#   'price': 3650.35,
#   'volume_24h': 3727222498,
#   'market_cap': 63796174445},
#  {'timestamp': '2019-01-11T23:50:00Z',
#   'price': 3657.02,
#   'volume_24h': 3754101170,
#   'market_cap': 63912833483},
#  {'timestamp': '2019-01-11T23:55:00Z',
#   'price': 3655.71,
#   'volume_24h': 3761766983,
#   'market_cap': 63890009633},
#  {'timestamp': '2019-01-12T00:00:00Z',
#   'price': 3660.91,
#   'volume_24h': 3766356337,
#   'market_cap': 63980917362},
#  {'timestamp': '2019-01-12T00:05:00Z',
#   'price': 3656.78,
#   'volume_24h': 3739245654,
#   'market_cap': 63908721380},
#  {'timestamp': '2019-01-12T00:10:00Z',
#   'price': 3657.4,
#   'volume_24h': 3729424285,
#   'market_cap': 63919626278},
#  {'timestamp': '2019-01-12T00:15:00Z',
#   'price': 3660.05,
#   'volume_24h': 3727204011,
#   'market_cap': 63965832247},
#  {'timestamp': '2019-01-12T00:20:00Z',
#   'price': 3661.15,
#   'volume_24h': 3739410178,
#   'market_cap': 63985195005},
#  {'timestamp': '2019-01-12T00:25:00Z',
#   'price': 3664.75,
#   'volume_24h': 3744488997,
#   'market_cap': 64048069626},
#  {'timestamp': '2019-01-12T00:30:00Z',
#   'price': 3666.08,
#   'volume_24h': 3745678991,
#   'market_cap': 64071377629},
#  {'timestamp': '2019-01-12T00:35:00Z',
#   'price': 3666.4,
#   'volume_24h': 3748810901,
#   'market_cap': 64077003560},
#  {'timestamp': '2019-01-12T00:40:00Z',
#   'price': 3668.74,
#   'volume_24h': 3753801627,
#   'market_cap': 64117984287},
#  {'timestamp': '2019-01-12T00:45:00Z',
#   'price': 3671.59,
#   'volume_24h': 3749308617,
#   'market_cap': 64167730186},
#  {'timestamp': '2019-01-12T00:50:00Z',
#   'price': 3668.16,
#   'volume_24h': 3747374570,
#   'market_cap': 64108031435},
#  {'timestamp': '2019-01-12T00:55:00Z',
#   'price': 3666.04,
#   'volume_24h': 3747243541,
#   'market_cap': 64070870879},
#  {'timestamp': '2019-01-12T01:00:00Z',
#   'price': 3664.95,
#   'volume_24h': 3745459997,
#   'market_cap': 64051837825},
#  {'timestamp': '2019-01-12T01:05:00Z',
#   'price': 3660.88,
#   'volume_24h': 3714803730,
#   'market_cap': 63980709761},
#  {'timestamp': '2019-01-12T01:10:00Z',
#   'price': 3661.14,
#   'volume_24h': 3706835651,
#   'market_cap': 63985360196},
#  {'timestamp': '2019-01-12T01:15:00Z',
#   'price': 3659.82,
#   'volume_24h': 3703597187,
#   'market_cap': 63962365101},
#  {'timestamp': '2019-01-12T01:20:00Z',
#   'price': 3656.76,
#   'volume_24h': 3707335025,
#   'market_cap': 63908771299},
#  {'timestamp': '2019-01-12T01:25:00Z',
#   'price': 3658.51,
#   'volume_24h': 3714064219,
#   'market_cap': 63939456658},
#  {'timestamp': '2019-01-12T01:30:00Z',
#   'price': 3659.24,
#   'volume_24h': 3716727009,
#   'market_cap': 63952233665},
#  {'timestamp': '2019-01-12T01:35:00Z',
#   'price': 3657.37,
#   'volume_24h': 3717337460,
#   'market_cap': 63919499723},
#  {'timestamp': '2019-01-12T01:40:00Z',
#   'price': 3657.46,
#   'volume_24h': 3716205906,
#   'market_cap': 63921085703},
#  {'timestamp': '2019-01-12T01:45:00Z',
#   'price': 3656.49,
#   'volume_24h': 3714402183,
#   'market_cap': 63904182605},
#  {'timestamp': '2019-01-12T01:50:00Z',
#   'price': 3657.19,
#   'volume_24h': 3717911360,
#   'market_cap': 63916348351},
#  {'timestamp': '2019-01-12T01:55:00Z',
#   'price': 3656.53,
#   'volume_24h': 3717865838,
#   'market_cap': 63905120595},
#  {'timestamp': '2019-01-12T02:00:00Z',
#   'price': 3655.92,
#   'volume_24h': 3717383148,
#   'market_cap': 63894402559},
#  {'timestamp': '2019-01-12T02:05:00Z',
#   'price': 3655.93,
#   'volume_24h': 3700111129,
#   'market_cap': 63894742779},
#  {'timestamp': '2019-01-12T02:10:00Z',
#   'price': 3655.8,
#   'volume_24h': 3696776284,
#   'market_cap': 63892470196},
#  {'timestamp': '2019-01-12T02:15:00Z',
#   'price': 3654.52,
#   'volume_24h': 3696023231,
#   'market_cap': 63870099811},
#  {'timestamp': '2019-01-12T02:20:00Z',
#   'price': 3652.86,
#   'volume_24h': 3693685688,
#   'market_cap': 63841106879},
#  {'timestamp': '2019-01-12T02:25:00Z',
#   'price': 3651.31,
#   'volume_24h': 3691635951,
#   'market_cap': 63814047959},
#  {'timestamp': '2019-01-12T02:30:00Z',
#   'price': 3655.34,
#   'volume_24h': 3698276857,
#   'market_cap': 63884356824},
#  {'timestamp': '2019-01-12T02:35:00Z',
#   'price': 3654.89,
#   'volume_24h': 3694831680,
#   'market_cap': 63876722350},
#  {'timestamp': '2019-01-12T02:40:00Z',
#   'price': 3652.33,
#   'volume_24h': 3689099313,
#   'market_cap': 63831948611},
#  {'timestamp': '2019-01-12T02:45:00Z',
#   'price': 3653.16,
#   'volume_24h': 3690216055,
#   'market_cap': 63846478489},
#  {'timestamp': '2019-01-12T02:50:00Z',
#   'price': 3653.7,
#   'volume_24h': 3690849369,
#   'market_cap': 63855972273},
#  {'timestamp': '2019-01-12T02:55:00Z',
#   'price': 3657.27,
#   'volume_24h': 3702711089,
#   'market_cap': 63918319600},
#  {'timestamp': '2019-01-12T03:00:00Z',
#   'price': 3658.38,
#   'volume_24h': 3707832831,
#   'market_cap': 63937668526},
#  {'timestamp': '2019-01-12T03:05:00Z',
#   'price': 3659.69,
#   'volume_24h': 3680786199,
#   'market_cap': 63960555205},
#  {'timestamp': '2019-01-12T03:10:00Z',
#   'price': 3659.65,
#   'volume_24h': 3683915690,
#   'market_cap': 63960120750},
#  {'timestamp': '2019-01-12T03:15:00Z',
#   'price': 3660.06,
#   'volume_24h': 3686413637,
#   'market_cap': 63967152418},
#  {'timestamp': '2019-01-12T03:20:00Z',
#   'price': 3663.28,
#   'volume_24h': 3699236571,
#   'market_cap': 64023462676},
#  {'timestamp': '2019-01-12T03:25:00Z',
#   'price': 3660,
#   'volume_24h': 3702357218,
#   'market_cap': 63966308878},
#  {'timestamp': '2019-01-12T03:30:00Z',
#   'price': 3661.5,
#   'volume_24h': 3705282974,
#   'market_cap': 63992385127},
#  {'timestamp': '2019-01-12T03:35:00Z',
#   'price': 3661.38,
#   'volume_24h': 3705148737,
#   'market_cap': 63990266347},
#  {'timestamp': '2019-01-12T03:40:00Z',
#   'price': 3661.74,
#   'volume_24h': 3703171878,
#   'market_cap': 63996713897},
#  {'timestamp': '2019-01-12T03:45:00Z',
#   'price': 3662.3,
#   'volume_24h': 3702622871,
#   'market_cap': 64006445146},
#  {'timestamp': '2019-01-12T03:50:00Z',
#   'price': 3663.23,
#   'volume_24h': 3702322682,
#   'market_cap': 64022704402},
#  {'timestamp': '2019-01-12T03:55:00Z',
#   'price': 3665.64,
#   'volume_24h': 3703999531,
#   'market_cap': 64064775121},
#  {'timestamp': '2019-01-12T04:00:00Z',
#   'price': 3663.93,
#   'volume_24h': 3702357054,
#   'market_cap': 64034972071},
#  {'timestamp': '2019-01-12T04:05:00Z',
#   'price': 3663.48,
#   'volume_24h': 3675948091,
#   'market_cap': 64027080582},
#  {'timestamp': '2019-01-12T04:10:00Z',
#   'price': 3663.53,
#   'volume_24h': 3677452740,
#   'market_cap': 64027983490},
#  {'timestamp': '2019-01-12T04:15:00Z',
#   'price': 3662.02,
#   'volume_24h': 3674307486,
#   'market_cap': 64001567623},
#  {'timestamp': '2019-01-12T04:20:00Z',
#   'price': 3661.6,
#   'volume_24h': 3670744879,
#   'market_cap': 63994181346},
#  {'timestamp': '2019-01-12T04:25:00Z',
#   'price': 3663.48,
#   'volume_24h': 3664440225,
#   'market_cap': 64027030464},
#  {'timestamp': '2019-01-12T04:30:00Z',
#   'price': 3660.61,
#   'volume_24h': 3650836336,
#   'market_cap': 63976997440},
#  {'timestamp': '2019-01-12T04:35:00Z',
#   'price': 3660.54,
#   'volume_24h': 3645487638,
#   'market_cap': 63975809457},
#  {'timestamp': '2019-01-12T04:40:00Z',
#   'price': 3659.91,
#   'volume_24h': 3640470370,
#   'market_cap': 63964814770},
#  {'timestamp': '2019-01-12T04:45:00Z',
#   'price': 3659.57,
#   'volume_24h': 3639069526,
#   'market_cap': 63958783557},
#  {'timestamp': '2019-01-12T04:50:00Z',
#   'price': 3659.51,
#   'volume_24h': 3639490595,
#   'market_cap': 63957778952},
#  {'timestamp': '2019-01-12T04:55:00Z',
#   'price': 3657.54,
#   'volume_24h': 3639403362,
#   'market_cap': 63923362057},
#  {'timestamp': '2019-01-12T05:00:00Z',
#   'price': 3658.3,
#   'volume_24h': 3637270146,
#   'market_cap': 63936621600},
#  {'timestamp': '2019-01-12T05:05:00Z',
#   'price': 3656.44,
#   'volume_24h': 3613410521,
#   'market_cap': 63904253924},
#  {'timestamp': '2019-01-12T05:10:00Z',
#   'price': 3658.89,
#   'volume_24h': 3607147573,
#   'market_cap': 63947006738},
#  {'timestamp': '2019-01-12T05:15:00Z',
#   'price': 3659.98,
#   'volume_24h': 3609636170,
#   'market_cap': 63966076556},
#  {'timestamp': '2019-01-12T05:20:00Z',
#   'price': 3659.52,
#   'volume_24h': 3604612994,
#   'market_cap': 63958127575},
#  {'timestamp': '2019-01-12T05:25:00Z',
#   'price': 3660.73,
#   'volume_24h': 3605055869,
#   'market_cap': 63979174569},
#  {'timestamp': '2019-01-12T05:30:00Z',
#   'price': 3660.4,
#   'volume_24h': 3603711579,
#   'market_cap': 63973453506},
#  {'timestamp': '2019-01-12T05:35:00Z',
#   'price': 3659.1,
#   'volume_24h': 3606185955,
#   'market_cap': 63950735666},
#  {'timestamp': '2019-01-12T05:40:00Z',
#   'price': 3660.15,
#   'volume_24h': 3608189547,
#   'market_cap': 63969114442},
#  {'timestamp': '2019-01-12T05:45:00Z',
#   'price': 3658.86,
#   'volume_24h': 3608787804,
#   'market_cap': 63946619949},
#  {'timestamp': '2019-01-12T05:50:00Z',
#   'price': 3658.07,
#   'volume_24h': 3607516219,
#   'market_cap': 63932939010},
#  {'timestamp': '2019-01-12T05:55:00Z',
#   'price': 3658.55,
#   'volume_24h': 3608646750,
#   'market_cap': 63941325609},
#  {'timestamp': '2019-01-12T06:00:00Z',
#   'price': 3658.75,
#   'volume_24h': 3607872782,
#   'market_cap': 63944735916},
#  {'timestamp': '2019-01-12T06:05:00Z',
#   'price': 3660.36,
#   'volume_24h': 3584914551,
#   'market_cap': 63972876106},
#  {'timestamp': '2019-01-12T06:10:00Z',
#   'price': 3659.84,
#   'volume_24h': 3579618632,
#   'market_cap': 63963844668},
#  {'timestamp': '2019-01-12T06:15:00Z',
#   'price': 3659.58,
#   'volume_24h': 3579085746,
#   'market_cap': 63959325697},
#  {'timestamp': '2019-01-12T06:20:00Z',
#   'price': 3659.93,
#   'volume_24h': 3580780366,
#   'market_cap': 63965449949},
#  {'timestamp': '2019-01-12T06:25:00Z',
#   'price': 3656.53,
#   'volume_24h': 3573679993,
#   'market_cap': 63906118700},
#  {'timestamp': '2019-01-12T06:30:00Z',
#   'price': 3655.08,
#   'volume_24h': 3567871108,
#   'market_cap': 63880768647},
#  {'timestamp': '2019-01-12T06:35:00Z',
#   'price': 3653.71,
#   'volume_24h': 3566073745,
#   'market_cap': 63856961386},
#  {'timestamp': '2019-01-12T06:40:00Z',
#   'price': 3652.46,
#   'volume_24h': 3566848197,
#   'market_cap': 63834975486},
#  {'timestamp': '2019-01-12T06:45:00Z',
#   'price': 3649.75,
#   'volume_24h': 3568312242,
#   'market_cap': 63787652775},
#  {'timestamp': '2019-01-12T06:50:00Z',
#   'price': 3651.42,
#   'volume_24h': 3571208319,
#   'market_cap': 63816879186},
#  {'timestamp': '2019-01-12T06:55:00Z',
#   'price': 3651.71,
#   'volume_24h': 3571557571,
#   'market_cap': 63822195236},
#  {'timestamp': '2019-01-12T07:00:00Z',
#   'price': 3645.52,
#   'volume_24h': 3568659111,
#   'market_cap': 63713951410},
#  {'timestamp': '2019-01-12T07:05:00Z',
#   'price': 3648.18,
#   'volume_24h': 3553032964,
#   'market_cap': 63760623440},
#  {'timestamp': '2019-01-12T07:10:00Z',
#   'price': 3647.64,
#   'volume_24h': 3554093424,
#   'market_cap': 63751076171},
#  {'timestamp': '2019-01-12T07:15:00Z',
#   'price': 3646.98,
#   'volume_24h': 3551531730,
#   'market_cap': 63739557608},
#  {'timestamp': '2019-01-12T07:20:00Z',
#   'price': 3645.4,
#   'volume_24h': 3545057525,
#   'market_cap': 63711930360},
#  {'timestamp': '2019-01-12T07:25:00Z',
#   'price': 3645.6,
#   'volume_24h': 3543828229,
#   'market_cap': 63715457225},
#  {'timestamp': '2019-01-12T07:30:00Z',
#   'price': 3644.66,
#   'volume_24h': 3540437332,
#   'market_cap': 63699115270},
#  {'timestamp': '2019-01-12T07:35:00Z',
#   'price': 3646.89,
#   'volume_24h': 3540527101,
#   'market_cap': 63738216429},
#  {'timestamp': '2019-01-12T07:40:00Z',
#   'price': 3646.63,
#   'volume_24h': 3539260949,
#   'market_cap': 63733650581},
#  {'timestamp': '2019-01-12T07:45:00Z',
#   'price': 3645.9,
#   'volume_24h': 3539309702,
#   'market_cap': 63721049635},
#  {'timestamp': '2019-01-12T07:50:00Z',
#   'price': 3646.07,
#   'volume_24h': 3540099750,
#   'market_cap': 63723961405},
#  {'timestamp': '2019-01-12T07:55:00Z',
#   'price': 3648.62,
#   'volume_24h': 3543621079,
#   'market_cap': 63768498847},
#  {'timestamp': '2019-01-12T08:00:00Z',
#   'price': 3647.95,
#   'volume_24h': 3544876869,
#   'market_cap': 63756943260},
#  {'timestamp': '2019-01-12T08:05:00Z',
#   'price': 3649.51,
#   'volume_24h': 3526971856,
#   'market_cap': 63784215235},
#  {'timestamp': '2019-01-12T08:10:00Z',
#   'price': 3649.99,
#   'volume_24h': 3515303579,
#   'market_cap': 63792496632},
#  {'timestamp': '2019-01-12T08:15:00Z',
#   'price': 3652.99,
#   'volume_24h': 3512197752,
#   'market_cap': 63845066773},
#  {'timestamp': '2019-01-12T08:20:00Z',
#   'price': 3649.85,
#   'volume_24h': 3506067268,
#   'market_cap': 63790171671},
#  {'timestamp': '2019-01-12T08:25:00Z',
#   'price': 3648.55,
#   'volume_24h': 3503704645,
#   'market_cap': 63767442549},
#  {'timestamp': '2019-01-12T08:30:00Z',
#   'price': 3652.34,
#   'volume_24h': 3508236774,
#   'market_cap': 63833622264},
#  {'timestamp': '2019-01-12T08:35:00Z',
#   'price': 3649.51,
#   'volume_24h': 3506297060,
#   'market_cap': 63784110960},
#  {'timestamp': '2019-01-12T08:40:00Z',
#   'price': 3649.37,
#   'volume_24h': 3505437008,
#   'market_cap': 63781730762},
#  {'timestamp': '2019-01-12T08:45:00Z',
#   'price': 3649.03,
#   'volume_24h': 3500757044,
#   'market_cap': 63775763154},
#  {'timestamp': '2019-01-12T08:50:00Z',
#   'price': 3648.25,
#   'volume_24h': 3489988277,
#   'market_cap': 63762341883},
#  {'timestamp': '2019-01-12T08:55:00Z',
#   'price': 3647.43,
#   'volume_24h': 3480741556,
#   'market_cap': 63748027728},
#  {'timestamp': '2019-01-12T09:00:00Z',
#   'price': 3644.96,
#   'volume_24h': 3472969381,
#   'market_cap': 63704817925},
#  {'timestamp': '2019-01-12T09:05:00Z',
#   'price': 3647.34,
#   'volume_24h': 3459367837,
#   'market_cap': 63746500267},
#  {'timestamp': '2019-01-12T09:10:00Z',
#   'price': 3646.94,
#   'volume_24h': 3454158589,
#   'market_cap': 63739434530},
#  {'timestamp': '2019-01-12T09:15:00Z',
#   'price': 3644.17,
#   'volume_24h': 3452398811,
#   'market_cap': 63691192222},
#  {'timestamp': '2019-01-12T09:20:00Z',
#   'price': 3643.95,
#   'volume_24h': 3445245206,
#   'market_cap': 63687341241},
#  {'timestamp': '2019-01-12T09:25:00Z',
#   'price': 3645.02,
#   'volume_24h': 3445412680,
#   'market_cap': 63706002279},
#  {'timestamp': '2019-01-12T09:30:00Z',
#   'price': 3644.03,
#   'volume_24h': 3444487552,
#   'market_cap': 63688810203},
#  {'timestamp': '2019-01-12T09:35:00Z',
#   'price': 3644.37,
#   'volume_24h': 3442156502,
#   'market_cap': 63694629886},
#  {'timestamp': '2019-01-12T09:40:00Z',
#   'price': 3643.66,
#   'volume_24h': 3437266209,
#   'market_cap': 63682225021},
#  {'timestamp': '2019-01-12T09:45:00Z',
#   'price': 3640.93,
#   'volume_24h': 3438368841,
#   'market_cap': 63634502097},
#  {'timestamp': '2019-01-12T09:50:00Z',
#   'price': 3640.29,
#   'volume_24h': 3441685888,
#   'market_cap': 63623367288},
#  {'timestamp': '2019-01-12T09:55:00Z',
#   'price': 3638.69,
#   'volume_24h': 3441828823,
#   'market_cap': 63595651971},
#  {'timestamp': '2019-01-12T10:00:00Z',
#   'price': 3645.39,
#   'volume_24h': 3445708853,
#   'market_cap': 63712639254},
#  {'timestamp': '2019-01-12T10:05:00Z',
#   'price': 3644.28,
#   'volume_24h': 3424958639,
#   'market_cap': 63693209042},
#  {'timestamp': '2019-01-12T10:10:00Z',
#   'price': 3645.22,
# ...
#   'price': 3542.86,
#   'volume_24h': 3078450825,
#   'market_cap': 61930074806},
#  {'timestamp': '2019-01-14T00:00:00Z',
#   'price': 3545.07,
#   'volume_24h': 3083601858,
#   'market_cap': 61968539534},
#  {'timestamp': '2019-01-14T00:05:00Z',
#   'price': 3546.86,
#   'volume_24h': 3071166473,
#   'market_cap': 61999903188},
#  {'timestamp': '2019-01-14T00:10:00Z',
#   'price': 3547.44,
#   'volume_24h': 3072629854,
#   'market_cap': 62010102618},
#  {'timestamp': '2019-01-14T00:15:00Z',
#   'price': 3546.59,
#   'volume_24h': 3074601641,
#   'market_cap': 61995191838},
#  {'timestamp': '2019-01-14T00:20:00Z',
#   'price': 3546.23,
#   'volume_24h': 3076288310,
#   'market_cap': 61988946395},
#  {'timestamp': '2019-01-14T00:25:00Z',
#   'price': 3543.75,
#   'volume_24h': 3081533611,
#   'market_cap': 61945592898},
#  {'timestamp': '2019-01-14T00:30:00Z',
#   'price': 3541.61,
#   'volume_24h': 3080391023,
#   'market_cap': 61908291905},
#  {'timestamp': '2019-01-14T00:35:00Z',
#   'price': 3542.78,
#   'volume_24h': 3082396439,
#   'market_cap': 61928749434},
#  {'timestamp': '2019-01-14T00:40:00Z',
#   'price': 3543.58,
#   'volume_24h': 3083558724,
#   'market_cap': 61942610174},
#  {'timestamp': '2019-01-14T00:45:00Z',
#   'price': 3546.85,
#   'volume_24h': 3090183413,
#   'market_cap': 61999829063},
#  {'timestamp': '2019-01-14T00:50:00Z',
#   'price': 3547.1,
#   'volume_24h': 3096293452,
#   'market_cap': 62004147281},
#  {'timestamp': '2019-01-14T00:55:00Z',
#   'price': 3546.48,
#   'volume_24h': 3095618835,
#   'market_cap': 61993475829},
#  {'timestamp': '2019-01-14T01:00:00Z',
#   'price': 3547.21,
#   'volume_24h': 3098711092,
#   'market_cap': 62006119008},
#  {'timestamp': '2019-01-14T01:05:00Z',
#   'price': 3549.32,
#   'volume_24h': 3086965328,
#   'market_cap': 62043148159},
#  {'timestamp': '2019-01-14T01:10:00Z',
#   'price': 3549.27,
#   'volume_24h': 3088841818,
#   'market_cap': 62042233797},
#  {'timestamp': '2019-01-14T01:15:00Z',
#   'price': 3548.96,
#   'volume_24h': 3094828389,
#   'market_cap': 62036808195},
#  {'timestamp': '2019-01-14T01:20:00Z',
#   'price': 3551,
#   'volume_24h': 3098925899,
#   'market_cap': 62072627818},
#  {'timestamp': '2019-01-14T01:25:00Z',
#   'price': 3552.3,
#   'volume_24h': 3105891645,
#   'market_cap': 62095321800},
#  {'timestamp': '2019-01-14T01:30:00Z',
#   'price': 3553.8,
#   'volume_24h': 3109225692,
#   'market_cap': 62121508279},
#  {'timestamp': '2019-01-14T01:35:00Z',
#   'price': 3558.15,
#   'volume_24h': 3118168182,
#   'market_cap': 62197655535},
#  {'timestamp': '2019-01-14T01:40:00Z',
#   'price': 3556,
#   'volume_24h': 3122309263,
#   'market_cap': 62160176135},
#  {'timestamp': '2019-01-14T01:45:00Z',
#   'price': 3558.64,
#   'volume_24h': 3132090649,
#   'market_cap': 62206220252},
#  {'timestamp': '2019-01-14T01:50:00Z',
#   'price': 3560.68,
#   'volume_24h': 3138188611,
#   'market_cap': 62241915705},
#  {'timestamp': '2019-01-14T01:55:00Z',
#   'price': 3560.06,
#   'volume_24h': 3146632527,
#   'market_cap': 62231042810},
#  {'timestamp': '2019-01-14T02:00:00Z',
#   'price': 3560.65,
#   'volume_24h': 3150467063,
#   'market_cap': 62241481232},
#  {'timestamp': '2019-01-14T02:05:00Z',
#   'price': 3560.4,
#   'volume_24h': 3138771674,
#   'market_cap': 62237119958},
#  {'timestamp': '2019-01-14T02:10:00Z',
#   'price': 3560.13,
#   'volume_24h': 3142347782,
#   'market_cap': 62232375938},
#  {'timestamp': '2019-01-14T02:15:00Z',
#   'price': 3562.44,
#   'volume_24h': 3150475626,
#   'market_cap': 62272614623},
#  {'timestamp': '2019-01-14T02:20:00Z',
#   'price': 3561.12,
#   'volume_24h': 3158635143,
#   'market_cap': 62249574871},
#  {'timestamp': '2019-01-14T02:25:00Z',
#   'price': 3563.96,
#   'volume_24h': 3166293222,
#   'market_cap': 62299419534},
#  {'timestamp': '2019-01-14T02:30:00Z',
#   'price': 3564.27,
#   'volume_24h': 3171437140,
#   'market_cap': 62304859322},
#  {'timestamp': '2019-01-14T02:35:00Z',
#   'price': 3565.68,
#   'volume_24h': 3179902721,
#   'market_cap': 62329411183},
#  {'timestamp': '2019-01-14T02:40:00Z',
#   'price': 3565.25,
#   'volume_24h': 3180716382,
#   'market_cap': 62321958728},
#  {'timestamp': '2019-01-14T02:45:00Z',
#   'price': 3563.44,
#   'volume_24h': 3178176928,
#   'market_cap': 62290224761},
#  {'timestamp': '2019-01-14T02:50:00Z',
#   'price': 3563.75,
#   'volume_24h': 3182268411,
#   'market_cap': 62295899454},
#  {'timestamp': '2019-01-14T02:55:00Z',
#   'price': 3563.43,
#   'volume_24h': 3184528433,
#   'market_cap': 62290189331},
#  {'timestamp': '2019-01-14T03:00:00Z',
#   'price': 3565.14,
#   'volume_24h': 3188144634,
#   'market_cap': 62320230369},
#  {'timestamp': '2019-01-14T03:05:00Z',
#   'price': 3563.04,
#   'volume_24h': 3174170353,
#   'market_cap': 62283664207},
#  {'timestamp': '2019-01-14T03:10:00Z',
#   'price': 3562.86,
#   'volume_24h': 3174983015,
#   'market_cap': 62280397707},
#  {'timestamp': '2019-01-14T03:15:00Z',
#   'price': 3563.89,
#   'volume_24h': 3173211166,
#   'market_cap': 62298375927},
#  {'timestamp': '2019-01-14T03:20:00Z',
#   'price': 3562.41,
#   'volume_24h': 3174487826,
#   'market_cap': 62272635255},
#  {'timestamp': '2019-01-14T03:25:00Z',
#   'price': 3560.58,
#   'volume_24h': 3174873405,
#   'market_cap': 62240654865},
#  {'timestamp': '2019-01-14T03:30:00Z',
#   'price': 3560.48,
#   'volume_24h': 3172652217,
#   'market_cap': 62238979870},
#  {'timestamp': '2019-01-14T03:35:00Z',
#   'price': 3563.47,
#   'volume_24h': 3174485759,
#   'market_cap': 62291188296},
#  {'timestamp': '2019-01-14T03:40:00Z',
#   'price': 3559.57,
#   'volume_24h': 3174869914,
#   'market_cap': 62222978503},
#  {'timestamp': '2019-01-14T03:45:00Z',
#   'price': 3562.91,
#   'volume_24h': 3177854733,
#   'market_cap': 62281476912},
#  {'timestamp': '2019-01-14T03:50:00Z',
#   'price': 3562.94,
#   'volume_24h': 3188806986,
#   'market_cap': 62282084518},
#  {'timestamp': '2019-01-14T03:55:00Z',
#   'price': 3560.44,
#   'volume_24h': 3191938420,
#   'market_cap': 62238395654},
#  {'timestamp': '2019-01-14T04:00:00Z',
#   'price': 3563.56,
#   'volume_24h': 3197274095,
#   'market_cap': 62292852303},
#  {'timestamp': '2019-01-14T04:05:00Z',
#   'price': 3561.4,
#   'volume_24h': 3181599224,
#   'market_cap': 62255177441},
#  {'timestamp': '2019-01-14T04:10:00Z',
#   'price': 3564.6,
#   'volume_24h': 3179765201,
#   'market_cap': 62311207105},
#  {'timestamp': '2019-01-14T04:15:00Z',
#   'price': 3564.08,
#   'volume_24h': 3179746173,
#   'market_cap': 62302169771},
#  {'timestamp': '2019-01-14T04:20:00Z',
#   'price': 3562.3,
#   'volume_24h': 3182452085,
#   'market_cap': 62271064803},
#  {'timestamp': '2019-01-14T04:25:00Z',
#   'price': 3567.29,
#   'volume_24h': 3189489669,
#   'market_cap': 62358374835},
#  {'timestamp': '2019-01-14T04:30:00Z',
#   'price': 3565.26,
#   'volume_24h': 3188508596,
#   'market_cap': 62322939476},
#  {'timestamp': '2019-01-14T04:35:00Z',
#   'price': 3565.64,
#   'volume_24h': 3191336444,
#   'market_cap': 62329548349},
#  {'timestamp': '2019-01-14T04:40:00Z',
#   'price': 3565.09,
#   'volume_24h': 3193365157,
#   'market_cap': 62319868420},
#  {'timestamp': '2019-01-14T04:45:00Z',
#   'price': 3566.73,
#   'volume_24h': 3196030160,
#   'market_cap': 62348626021},
#  {'timestamp': '2019-01-14T04:50:00Z',
#   'price': 3566.24,
#   'volume_24h': 3200615737,
#   'market_cap': 62340010030},
#  {'timestamp': '2019-01-14T04:55:00Z',
#   'price': 3566.37,
#   'volume_24h': 3200123440,
#   'market_cap': 62342292095},
#  {'timestamp': '2019-01-14T05:00:00Z',
#   'price': 3566.8,
#   'volume_24h': 3202906311,
#   'market_cap': 62349846878},
#  {'timestamp': '2019-01-14T05:05:00Z',
#   'price': 3567.19,
#   'volume_24h': 3194136882,
#   'market_cap': 62356614149},
#  {'timestamp': '2019-01-14T05:10:00Z',
#   'price': 3569.14,
#   'volume_24h': 3199701836,
#   'market_cap': 62390826583},
#  {'timestamp': '2019-01-14T05:15:00Z',
#   'price': 3570.98,
#   'volume_24h': 3205723640,
#   'market_cap': 62423016310},
#  {'timestamp': '2019-01-14T05:20:00Z',
#   'price': 3570.46,
#   'volume_24h': 3209518109,
#   'market_cap': 62413928009},
#  {'timestamp': '2019-01-14T05:25:00Z',
#   'price': 3570.83,
#   'volume_24h': 3213117945,
#   'market_cap': 62420614239},
#  {'timestamp': '2019-01-14T05:30:00Z',
#   'price': 3570.47,
#   'volume_24h': 3216041195,
#   'market_cap': 62414371309},
#  {'timestamp': '2019-01-14T05:35:00Z',
#   'price': 3571.36,
#   'volume_24h': 3221474958,
#   'market_cap': 62430011212},
#  {'timestamp': '2019-01-14T05:40:00Z',
#   'price': 3572.37,
#   'volume_24h': 3229612028,
#   'market_cap': 62447588297},
#  {'timestamp': '2019-01-14T05:45:00Z',
#   'price': 3573.82,
#   'volume_24h': 3234850776,
#   'market_cap': 62473000944},
#  {'timestamp': '2019-01-14T05:50:00Z',
#   'price': 3575.77,
#   'volume_24h': 3247082750,
#   'market_cap': 62507078031},
#  {'timestamp': '2019-01-14T05:55:00Z',
#   'price': 3575.22,
#   'volume_24h': 3250599344,
#   'market_cap': 62497433233},
#  {'timestamp': '2019-01-14T06:00:00Z',
#   'price': 3573.99,
#   'volume_24h': 3253186227,
#   'market_cap': 62475999448},
#  {'timestamp': '2019-01-14T06:05:00Z',
#   'price': 3573.12,
#   'volume_24h': 3241306142,
#   'market_cap': 62460935697},
#  {'timestamp': '2019-01-14T06:10:00Z',
#   'price': 3573.78,
#   'volume_24h': 3247146762,
#   'market_cap': 62472421229},
#  {'timestamp': '2019-01-14T06:15:00Z',
#   'price': 3579.01,
#   'volume_24h': 3257462687,
#   'market_cap': 62563804102},
#  {'timestamp': '2019-01-14T06:20:00Z',
#   'price': 3574.98,
#   'volume_24h': 3259885521,
#   'market_cap': 62493449739},
#  {'timestamp': '2019-01-14T06:25:00Z',
#   'price': 3576.84,
#   'volume_24h': 3267574179,
#   'market_cap': 62525888954},
#  {'timestamp': '2019-01-14T06:30:00Z',
#   'price': 3578.45,
#   'volume_24h': 3273458118,
#   'market_cap': 62554128866},
#  {'timestamp': '2019-01-14T06:35:00Z',
#   'price': 3575.82,
#   'volume_24h': 3274169038,
#   'market_cap': 62508252523},
#  {'timestamp': '2019-01-14T06:40:00Z',
#   'price': 3577.25,
#   'volume_24h': 3280138827,
#   'market_cap': 62533231140},
#  {'timestamp': '2019-01-14T06:45:00Z',
#   'price': 3582.1,
#   'volume_24h': 3291348597,
#   'market_cap': 62618059232},
#  {'timestamp': '2019-01-14T06:50:00Z',
#   'price': 3582.2,
#   'volume_24h': 3297882822,
#   'market_cap': 62619696063},
#  {'timestamp': '2019-01-14T06:55:00Z',
#   'price': 3580.33,
#   'volume_24h': 3257017984,
#   'market_cap': 62587046738},
#  {'timestamp': '2019-01-14T07:00:00Z',
#   'price': 3577.07,
#   'volume_24h': 3255504433,
#   'market_cap': 62530022003},
#  {'timestamp': '2019-01-14T07:05:00Z',
#   'price': 3581.16,
#   'volume_24h': 3252815054,
#   'market_cap': 62601577253},
#  {'timestamp': '2019-01-14T07:10:00Z',
#   'price': 3586.02,
#   'volume_24h': 3267914793,
#   'market_cap': 62686592282},
#  {'timestamp': '2019-01-14T07:15:00Z',
#   'price': 3584.99,
#   'volume_24h': 3273952043,
#   'market_cap': 62668646892},
#  {'timestamp': '2019-01-14T07:20:00Z',
#   'price': 3584.13,
#   'volume_24h': 3276378275,
#   'market_cap': 62653575199},
#  {'timestamp': '2019-01-14T07:25:00Z',
#   'price': 3585.49,
#   'volume_24h': 3286103690,
#   'market_cap': 62677403229},
#  {'timestamp': '2019-01-14T07:30:00Z',
#   'price': 3584.29,
#   'volume_24h': 3290721699,
#   'market_cap': 62656446988},
#  {'timestamp': '2019-01-14T07:35:00Z',
#   'price': 3583.15,
#   'volume_24h': 3296707680,
#   'market_cap': 62636487050},
#  {'timestamp': '2019-01-14T07:40:00Z',
#   'price': 3582.26,
#   'volume_24h': 3299681040,
#   'market_cap': 62620912733},
#  {'timestamp': '2019-01-14T07:45:00Z',
#   'price': 3580.14,
#   'volume_24h': 3267960609,
#   'market_cap': 62583814851},
#  {'timestamp': '2019-01-14T07:50:00Z',
#   'price': 3580.68,
#   'volume_24h': 3303339680,
#   'market_cap': 62593311877},
#  {'timestamp': '2019-01-14T07:55:00Z',
#   'price': 3579.07,
#   'volume_24h': 3306008499,
#   'market_cap': 62565111907},
#  {'timestamp': '2019-01-14T08:00:00Z',
#   'price': 3578.67,
#   'volume_24h': 3311436300,
#   'market_cap': 62558178270},
#  {'timestamp': '2019-01-14T08:05:00Z',
#   'price': 3578.14,
#   'volume_24h': 3300706294,
#   'market_cap': 62549004939},
#  {'timestamp': '2019-01-14T08:10:00Z',
#   'price': 3577.37,
#   'volume_24h': 3301582794,
#   'market_cap': 62535551160},
#  {'timestamp': '2019-01-14T08:15:00Z',
#   'price': 3578.24,
#   'volume_24h': 3307120616,
#   'market_cap': 62550707499},
#  {'timestamp': '2019-01-14T08:20:00Z',
#   'price': 3579.45,
#   'volume_24h': 3310926334,
#   'market_cap': 62571874723},
#  {'timestamp': '2019-01-14T08:25:00Z',
#   'price': 3579.58,
#   'volume_24h': 3313632454,
#   'market_cap': 62574140644},
#  {'timestamp': '2019-01-14T08:30:00Z',
#   'price': 3577.89,
#   'volume_24h': 3316389862,
#   'market_cap': 62544583350},
#  {'timestamp': '2019-01-14T08:35:00Z',
#   'price': 3579.34,
#   'volume_24h': 3319635205,
#   'market_cap': 62570081213},
#  {'timestamp': '2019-01-14T08:40:00Z',
#   'price': 3578.41,
#   'volume_24h': 3322391326,
#   'market_cap': 62553880512},
#  {'timestamp': '2019-01-14T08:45:00Z',
#   'price': 3578.38,
#   'volume_24h': 3324849686,
#   'market_cap': 62553387935},
#  {'timestamp': '2019-01-14T08:50:00Z',
#   'price': 3577.54,
#   'volume_24h': 3324279709,
#   'market_cap': 62538621143},
#  {'timestamp': '2019-01-14T08:55:00Z',
#   'price': 3575.6,
#   'volume_24h': 3320455899,
#   'market_cap': 62504752042},
#  {'timestamp': '2019-01-14T09:00:00Z',
#   'price': 3578.98,
#   'volume_24h': 3328580872,
#   'market_cap': 62563719176},
#  {'timestamp': '2019-01-14T09:05:00Z',
#   'price': 3578.8,
#   'volume_24h': 3318653537,
#   'market_cap': 62560641172},
#  {'timestamp': '2019-01-14T09:10:00Z',
#   'price': 3575.29,
#   'volume_24h': 3315664689,
#   'market_cap': 62499223088},
#  {'timestamp': '2019-01-14T09:15:00Z',
#   'price': 3573.62,
#   'volume_24h': 3316864386,
#   'market_cap': 62470046232},
#  {'timestamp': '2019-01-14T09:20:00Z',
#   'price': 3573.69,
#   'volume_24h': 3324462561,
#   'market_cap': 62471351880},
#  {'timestamp': '2019-01-14T09:25:00Z',
#   'price': 3576.56,
#   'volume_24h': 3337352011,
#   'market_cap': 62521453677},
#  {'timestamp': '2019-01-14T09:30:00Z',
#   'price': 3578.03,
#   'volume_24h': 3345042357,
#   'market_cap': 62547143076},
#  {'timestamp': '2019-01-14T09:35:00Z',
#   'price': 3577,
#   'volume_24h': 3347737301,
#   'market_cap': 62529339228},
#  {'timestamp': '2019-01-14T09:40:00Z',
#   'price': 3579.04,
#   'volume_24h': 3353529398,
#   'market_cap': 62564926766},
#  {'timestamp': '2019-01-14T09:45:00Z',
#   'price': 3579.45,
#   'volume_24h': 3354294067,
#   'market_cap': 62572098391},
#  {'timestamp': '2019-01-14T09:50:00Z',
#   'price': 3578.74,
#   'volume_24h': 3351723501,
#   'market_cap': 62559711940},
#  {'timestamp': '2019-01-14T09:55:00Z',
#   'price': 3579.6,
#   'volume_24h': 3356574648,
#   'market_cap': 62574813434},
#  {'timestamp': '2019-01-14T10:00:00Z',
#   'price': 3579.45,
#   'volume_24h': 3356763288,
#   'market_cap': 62572091858},
#  {'timestamp': '2019-01-14T10:05:00Z',
#   'price': 3585.08,
#   'volume_24h': 3365268752,
#   'market_cap': 62670494692},
#  {'timestamp': '2019-01-14T10:10:00Z',
#   'price': 3588.51,
#   'volume_24h': 3373431907,
#   'market_cap': 62730460968},
#  {'timestamp': '2019-01-14T10:15:00Z',
#   'price': 3582.76,
#   'volume_24h': 3372808104,
#   'market_cap': 62630110847},
#  {'timestamp': '2019-01-14T10:20:00Z',
#   'price': 3581.16,
#   'volume_24h': 3380177739,
#   'market_cap': 62602006430},
#  {'timestamp': '2019-01-14T10:25:00Z',
#   'price': 3580.58,
#   'volume_24h': 3385717506,
#   'market_cap': 62592016450},
#  {'timestamp': '2019-01-14T10:30:00Z',
#   'price': 3580.27,
#   'volume_24h': 3388937187,
#   'market_cap': 62586477553},
#  {'timestamp': '2019-01-14T10:35:00Z',
#   'price': 3577.14,
#   'volume_24h': 3387375960,
#   'market_cap': 62531857843},
#  {'timestamp': '2019-01-14T10:40:00Z',
#   'price': 3571.57,
#   'volume_24h': 3387677829,
#   'market_cap': 62434564359},
#  {'timestamp': '2019-01-14T10:45:00Z',
#   'price': 3575.08,
#   'volume_24h': 3395468856,
#   'market_cap': 62495918805},
#  {'timestamp': '2019-01-14T10:50:00Z',
#   'price': 3573.21,
#   'volume_24h': 3396050680,
#   'market_cap': 62463239211},
#  {'timestamp': '2019-01-14T10:55:00Z',
#   'price': 3572.62,
#   'volume_24h': 3399521378,
#   'market_cap': 62452940880},
#  {'timestamp': '2019-01-14T11:00:00Z',
#   'price': 3572.48,
#   'volume_24h': 3401777575,
#   'market_cap': 62450514042},
#  {'timestamp': '2019-01-14T11:05:00Z',
#   'price': 3574.1,
#   'volume_24h': 3394560769,
#   'market_cap': 62478899479},
#  {'timestamp': '2019-01-14T11:10:00Z',
#   'price': 3573.91,
#   'volume_24h': 3397081095,
#   'market_cap': 62475473477},
#  {'timestamp': '2019-01-14T11:15:00Z',
#   'price': 3572.34,
#   'volume_24h': 3397575360,
#   'market_cap': 62448038610}]

# %%
---
